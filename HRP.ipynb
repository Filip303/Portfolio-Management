# %%
import yfinance as yf
import pandas as pd
from pypfopt import HRPOpt, risk_models, expected_returns
import matplotlib.pyplot as plt

tickers = ['BTC-USD','O','MVUS.MI','EGLN.L','MSTR']
data = yf.download(tickers, period='10y')['Adj Close']

returns = data.pct_change().dropna()

cov_matrix = risk_models.sample_cov(returns)

hrp = HRPOpt(returns)
weights = hrp.optimize()

print('Pesos de la cartera HRP:')
print(weights)

pd.Series(weights).plot.pie(figsize=(10,10), autopct='%1.1f%%')
plt.title('Composición de la cartera optimizada por HRP')
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed
# <ipython-input-16-4abf2b42ddf1>:9: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = data.pct_change().dropna()
# /usr/local/lib/python3.10/dist-packages/pypfopt/hierarchical_portfolio.py:138: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.51929836 0.51929836]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   w[first_cluster] *= alpha  # weight 1
# Pesos de la cartera HRP:
# OrderedDict([('BTC-USD', 0.02151584148431003), ('EGLN.L', 0.49778251791865297), ('MSTR', 0.021020556189659742), ('MVUS.MI', 0.3469487629916409), ('O', 0.11273232141573637)])

# %%
import yfinance as yf
import quantstats as qs
import pandas as pd

# Paso 1: Descargar los datos de los activos
tickers = ['URTH', 'BTC-USD','MSTR','O','MVUS.MI','EGLN.L']
data = yf.download(tickers, period='10y')['Adj Close']

# Asegurarse de que todas las fechas sean tz-naive (sin zona horaria)
data.index = data.index.tz_localize(None)

# Paso 2: Calcular los retornos diarios
returns = data.pct_change().dropna()

# Paso 3: Seleccionar URTH como benchmark y calcular los retornos de la cartera óptima
# Cambiar de un set a un dict para optimal_weights
optimal_weights = {'BTC-USD': 0.02151584148431003,
                   'EGLN.L': 0.49778251791865297,
                   'MSTR': 0.021020556189659742,
                   'MVUS.MI': 0.3469487629916409,
                   'O': 0.11273232141573637}

# Filtrar los retornos de los activos en la cartera y calcular los retornos ponderados
selected_returns = returns[list(optimal_weights.keys())]
portfolio_returns = (selected_returns * pd.Series(optimal_weights)).sum(axis=1)

# Paso 4: Definir la tasa libre de riesgo anual y convertirla a diaria
risk_free_rate_annual = 0.025
risk_free_rate_daily = risk_free_rate_annual / 252

# Generar el informe completo con QuantStats
qs.reports.full(portfolio_returns, benchmark=returns['URTH'], rf=risk_free_rate_daily)
# Out:
# [*********************100%***********************]  6 of 6 completed
# <ipython-input-17-a169188c006b>:13: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = data.pct_change().dropna()
# [Performance Metrics]
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:86: FutureWarning: The behavior of DataFrame.prod with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# ...
